# %%
from mpl_toolkits.basemap import Basemap
from itertools import izip
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection
# %matplotlib inline

# %%
fig = plt.figure(figsize=(20, 10))
m = Basemap(width=800000, height=550000, resolution='l', projection='aea',
                lat_1=37., lat_2=41, lon_0=-105.55, lat_0=39)
m.readshapefile('data/CO_counties/tl_2009_08_cousub', 'counties')
m.tissot(-104, 37, 0.10, 100, facecolor='green', zorder=10,alpha=0.5)

# %%
m.tissot?
